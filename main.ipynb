# %%
x = 1
y = 2

# %%
x + y
# Out:
# 3

# %%
import numpy as np

# %%
np.__version__
# Out:
# '1.24.3'

# %%
import pandas as pd

# %%
df = pd.read_csv('./test.csv')

# %%
df
# Out:
#          album           artist  price
# 0    lateralus             tool   13.0
# 1       aenima             tool   12.0
# 2  10,000 days             tool   14.0
# 3   down in it  nine inch nails    3.0
# 4       broken  nine inch nails    6.0
